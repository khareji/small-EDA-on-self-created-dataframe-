# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
name=np.random.choice(["padam","khare","nirmal","singh","shikha","prashant","rishav"],size=50)
age=np.random.randint(low=20, high=35,size=50)
blood=np.random.choice(["a","b","c"],size=50)

# %%
data={'Name':name,"Age":age,"Blood":blood}

# %%
df=pd.DataFrame(data)
df
# Out:
#         Name  Age Blood
# 0     rishav   20     a
# 1     nirmal   21     a
# 2     nirmal   30     a
# 3   prashant   27     a
# 4     shikha   32     b
# 5      khare   21     b
# 6      singh   29     c
# 7      padam   20     a
# 8     nirmal   22     c
# 9      singh   25     b
# 10    shikha   25     b
# 11  prashant   22     c
# 12    rishav   22     b
# 13     singh   24     c
# 14     khare   34     b
# 15     singh   32     a
# 16    nirmal   28     b
# 17     padam   22     c
# 18     singh   20     c
# 19     khare   21     b
# 20    nirmal   26     c
# 21    shikha   25     a
# 22     khare   23     c
# 23     singh   30     c
# 24     khare   28     a
# 25    shikha   22     a
# 26    shikha   28     a
# 27     padam   22     b
# 28  prashant   29     a
# 29    shikha   32     c
# 30     singh   21     a
# 31     padam   29     c
# 32    nirmal   30     b
# 33    shikha   30     b
# 34     khare   21     c
# 35    shikha   31     a
# 36     singh   31     a
# ...

# %%
df.to_csv("nameageblood")

# %%
df.shape
# Out:
# (50, 3)

# %%
df.info
# Out:
# <bound method DataFrame.info of         Name  Age Blood
# 0     rishav   20     a
# 1     nirmal   21     a
# 2     nirmal   30     a
# 3   prashant   27     a
# 4     shikha   32     b
# 5      khare   21     b
# 6      singh   29     c
# 7      padam   20     a
# 8     nirmal   22     c
# 9      singh   25     b
# 10    shikha   25     b
# 11  prashant   22     c
# 12    rishav   22     b
# 13     singh   24     c
# 14     khare   34     b
# 15     singh   32     a
# 16    nirmal   28     b
# 17     padam   22     c
# 18     singh   20     c
# 19     khare   21     b
# 20    nirmal   26     c
# 21    shikha   25     a
# 22     khare   23     c
# 23     singh   30     c
# 24     khare   28     a
# 25    shikha   22     a
# 26    shikha   28     a
# 27     padam   22     b
# 28  prashant   29     a
# 29    shikha   32     c
# 30     singh   21     a
# 31     padam   29     c
# 32    nirmal   30     b
# 33    shikha   30     b
# 34     khare   21     c
# 35    shikha   31     a
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df["Name"])
# Out:
# pandas.core.series.Series

# %%
type(df["Age"])
# Out:
# pandas.core.series.Series

# %%
type(df["Blood"])
# Out:
# pandas.core.series.Series

# %%
df.dtypes
# Out:
# Name     object
# Age       int32
# Blood    object
# dtype: object

# %%
x=age
y=blood
plt.scatter(x,y,c = 'g',marker = '*')
plt.xlabel('AGE')
plt.ylabel('BLOOD')
plt.title('Scatter plot')
plt.show()

# %%
print(age)
print(blood)
# Out:
# [20 21 30 27 32 21 29 20 22 25 25 22 22 24 34 32 28 22 20 21 26 25 23 30
#  28 22 28 22 29 32 21 29 30 30 21 31 31 32 21 33 29 32 22 28 22 28 31 22
#  31 20]
# ['a' 'a' 'a' 'a' 'b' 'b' 'c' 'a' 'c' 'b' 'b' 'c' 'b' 'c' 'b' 'a' 'b' 'c'
#  'c' 'b' 'c' 'a' 'c' 'c' 'a' 'a' 'a' 'b' 'a' 'c' 'a' 'c' 'b' 'b' 'c' 'a'
#  'a' 'b' 'a' 'c' 'b' 'c' 'b' 'b' 'b' 'c' 'c' 'a' 'a' 'c']

# %%
x=blood
y=age
plt.plot(x,y,'r')
plt.xlabel("blood")
plt.ylabel('age')
plt.title('blood vs age')
plt.show()

# %%
x = name
y = age 

plt.bar(x, y)
plt.xlabel('Name')
plt.ylabel('Ages')
plt.title('Bar Graph') 
plt.show()

# %%
df[['age']].plot(kind='bar')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-35-5929c74a1dbd> in <module>
# ----> 1 df[['age']].plot(kind='bar')
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2932                 key = list(key)
#    2933             indexer = self.loc._convert_to_indexer(key, axis=1,
# -> 2934                                                    raise_missing=True)
#    2935
#    2936         # take() does not accept boolean indexers
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1352                 kwargs = {'raise_missing': True if is_setter else
#    1353                           raise_missing}
# -> 1354                 return self._get_listlike_indexer(obj, axis, **kwargs)[1]
#    1355         else:
#    1356             try:
#
# ...

# %%
x = blood
y = age 

plt.bar(x, y)
plt.xlabel('Blood')
plt.ylabel('Ages')
plt.title('Bar Graph') 
plt.show()

# %%
df["Age"].hist(bins=10)

# %%
x = age
plt.hist(x,bins = 10) 
plt.xlabel('Age')
plt.ylabel('No. of values')
plt.title("histogram") 
plt.show()

# %%
x =blood
plt.hist(x,bins =2) 
plt.xlabel('Blood')
plt.ylabel('No. of values')
plt.title("histogram") 
plt.show()

# %%
x = name
plt.hist(x,bins = 20) 
plt.xlabel('Name')
plt.ylabel('No. of values')
plt.title("histogram") 
plt.show()

# %%
x=age
plt.boxplot(x);
plt.show()

# %%
x = age
labels =name
plt.pie(x,  labels=labels,  autopct='%1.2f%%',shadow=True)
plt.title('dont know')
plt.show()

# %%
x = age
labels =name
colors = ['r', 'g', 'b', 'y']

#explode = (0, 0, 0, 0)  # explode 1st slice

# Plot
plt.pie(x,  labels=labels, colors=colors, autopct='%1.2f%%',shadow=True)
plt.title('dont know')
plt.show()

# %%
df['Age']
# Out:
# 0     20
# 1     21
# 2     30
# 3     27
# 4     32
# 5     21
# 6     29
# 7     20
# 8     22
# 9     25
# 10    25
# 11    22
# 12    22
# 13    24
# 14    34
# 15    32
# 16    28
# 17    22
# 18    20
# 19    21
# 20    26
# 21    25
# 22    23
# 23    30
# 24    28
# 25    22
# 26    28
# 27    22
# 28    29
# 29    32
# 30    21
# 31    29
# 32    30
# 33    30
# 34    21
# 35    31
# 36    31
# 37    32
# 38    21
# 39    33
# 40    29
# 41    32
# 42    22
# 43    28
# 44    22
# 45    28
# 46    31
# 47    22
# 48    31
# 49    20
# Name: Age, dtype: int32

# %%
City=np.random.choice(["allahabad","delhi","japan","america"], size=50)

# %%
df["city"]=City

# %%
df
# Out:
#         Name  Age Blood       city
# 0     rishav   20     a      delhi
# 1     nirmal   21     a    america
# 2     nirmal   30     a    america
# 3   prashant   27     a  allahabad
# 4     shikha   32     b  allahabad
# 5      khare   21     b    america
# 6      singh   29     c      delhi
# 7      padam   20     a  allahabad
# 8     nirmal   22     c  allahabad
# 9      singh   25     b  allahabad
# 10    shikha   25     b      japan
# 11  prashant   22     c  allahabad
# 12    rishav   22     b      delhi
# 13     singh   24     c      japan
# 14     khare   34     b      delhi
# 15     singh   32     a      delhi
# 16    nirmal   28     b  allahabad
# 17     padam   22     c      japan
# 18     singh   20     c      japan
# 19     khare   21     b    america
# 20    nirmal   26     c    america
# 21    shikha   25     a      japan
# 22     khare   23     c    america
# 23     singh   30     c      japan
# 24     khare   28     a      delhi
# 25    shikha   22     a      delhi
# ...

# %%
Temp=np.random.randint(low=35,high=95,size=50)
df['temp']=Temp
df
# Out:
#         Name  Age Blood       city  temp
# 0     rishav   20     a      delhi    57
# 1     nirmal   21     a    america    58
# 2     nirmal   30     a    america    87
# 3   prashant   27     a  allahabad    72
# 4     shikha   32     b  allahabad    59
# 5      khare   21     b    america    38
# 6      singh   29     c      delhi    86
# 7      padam   20     a  allahabad    74
# 8     nirmal   22     c  allahabad    41
# 9      singh   25     b  allahabad    75
# 10    shikha   25     b      japan    48
# 11  prashant   22     c  allahabad    62
# 12    rishav   22     b      delhi    56
# 13     singh   24     c      japan    59
# 14     khare   34     b      delhi    77
# 15     singh   32     a      delhi    92
# 16    nirmal   28     b  allahabad    72
# 17     padam   22     c      japan    85
# 18     singh   20     c      japan    74
# 19     khare   21     b    america    42
# 20    nirmal   26     c    america    82
# 21    shikha   25     a      japan    88
# ...

# %%
df.to_csv("nameageblood")

# %%
df
# Out:
#         Name  Age Blood       city  temp
# 0     rishav   20     a      delhi    57
# 1     nirmal   21     a    america    58
# 2     nirmal   30     a    america    87
# 3   prashant   27     a  allahabad    72
# 4     shikha   32     b  allahabad    59
# 5      khare   21     b    america    38
# 6      singh   29     c      delhi    86
# 7      padam   20     a  allahabad    74
# 8     nirmal   22     c  allahabad    41
# 9      singh   25     b  allahabad    75
# 10    shikha   25     b      japan    48
# 11  prashant   22     c  allahabad    62
# 12    rishav   22     b      delhi    56
# 13     singh   24     c      japan    59
# 14     khare   34     b      delhi    77
# 15     singh   32     a      delhi    92
# 16    nirmal   28     b  allahabad    72
# 17     padam   22     c      japan    85
# 18     singh   20     c      japan    74
# 19     khare   21     b    america    42
# 20    nirmal   26     c    america    82
# 21    shikha   25     a      japan    88
# ...

# %%
Gender=np.random.choice(['m','f'],size=50)

# %%
df['gender']=Gender

# %%
df.to_csv("nameageblood")
df
# Out:
#         Name  Age Blood       city  temp gender
# 0     rishav   20     a      delhi    57      f
# 1     nirmal   21     a    america    58      f
# 2     nirmal   30     a    america    87      m
# 3   prashant   27     a  allahabad    72      m
# 4     shikha   32     b  allahabad    59      m
# 5      khare   21     b    america    38      m
# 6      singh   29     c      delhi    86      m
# 7      padam   20     a  allahabad    74      f
# 8     nirmal   22     c  allahabad    41      f
# 9      singh   25     b  allahabad    75      f
# 10    shikha   25     b      japan    48      m
# 11  prashant   22     c  allahabad    62      f
# 12    rishav   22     b      delhi    56      m
# 13     singh   24     c      japan    59      m
# 14     khare   34     b      delhi    77      m
# 15     singh   32     a      delhi    92      m
# 16    nirmal   28     b  allahabad    72      m
# 17     padam   22     c      japan    85      m
# 18     singh   20     c      japan    74      f
# ...

# %%
Income=np.random.randint(low=1000,high=10000, size=50)

# %%
df["income"]=Income

# %%
df.to_csv("nameageblood")

# %%
df.dtypes
# Out:
# Name      object
# Age        int32
# Blood     object
# city      object
# temp       int32
# gender    object
# income     int32
# dtype: object

# %%
df.describe()
# Out:
#              Age       temp       income
# count  50.000000  50.000000    50.000000
# mean   26.120000  65.800000  5439.440000
# std     4.443018  18.535129  2526.679358
# min    20.000000  37.000000  1121.000000
# 25%    22.000000  48.500000  2930.750000
# 50%    26.500000  62.500000  5915.000000
# 75%    30.000000  84.500000  7638.000000
# max    34.000000  94.000000  9090.000000

# %%
df.corr()
# Out:
#              Age      temp    income
# Age     1.000000  0.237210 -0.112391
# temp    0.237210  1.000000 -0.224515
# income -0.112391 -0.224515  1.000000

# %%
import matplotlib.pyplot as plt
plt.matshow(df.corr())
plt.show()

# %%
sns.pairplot(df,hue="income")
# Out:
# C:\Users\Padam\Anaconda3\lib\site-packages\numpy\core\_methods.py:140: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# C:\Users\Padam\Anaconda3\lib\site-packages\numpy\core\_methods.py:132: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\Padam\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\Padam\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
df
# Out:
#         Name  Age Blood       city  temp gender  income
# 0     rishav   20     a      delhi    57      f    8626
# 1     nirmal   21     a    america    58      f    4611
# 2     nirmal   30     a    america    87      m    7032
# 3   prashant   27     a  allahabad    72      m    8101
# 4     shikha   32     b  allahabad    59      m    1354
# 5      khare   21     b    america    38      m    6211
# 6      singh   29     c      delhi    86      m    1595
# 7      padam   20     a  allahabad    74      f    8531
# 8     nirmal   22     c  allahabad    41      f    6595
# 9      singh   25     b  allahabad    75      f    2849
# 10    shikha   25     b      japan    48      m    7789
# 11  prashant   22     c  allahabad    62      f    7892
# 12    rishav   22     b      delhi    56      m    7557
# 13     singh   24     c      japan    59      m    5580
# 14     khare   34     b      delhi    77      m    6110
# 15     singh   32     a      delhi    92      m    2951
# ...

# %%
index=np.random.randint(low=0 ,high=50, size=50)

# %%
df["Index"]=index

# %%
df
# Out:
#         Name  Age Blood       city  temp gender  income  Index
# 0     rishav   20     a      delhi    57      f    8626     11
# 1     nirmal   21     a    america    58      f    4611     35
# 2     nirmal   30     a    america    87      m    7032     12
# 3   prashant   27     a  allahabad    72      m    8101     15
# 4     shikha   32     b  allahabad    59      m    1354     35
# 5      khare   21     b    america    38      m    6211     29
# 6      singh   29     c      delhi    86      m    1595     46
# 7      padam   20     a  allahabad    74      f    8531     28
# 8     nirmal   22     c  allahabad    41      f    6595     26
# 9      singh   25     b  allahabad    75      f    2849      5
# 10    shikha   25     b      japan    48      m    7789     14
# 11  prashant   22     c  allahabad    62      f    7892     29
# 12    rishav   22     b      delhi    56      m    7557     45
# 13     singh   24     c      japan    59      m    5580     16
# ...

# %%
df.drop(["Index"], axis=1)
# Out:
#         Name  Age Blood       city  temp gender  income
# 0     rishav   20     a      delhi    57      f    8626
# 1     nirmal   21     a    america    58      f    4611
# 2     nirmal   30     a    america    87      m    7032
# 3   prashant   27     a  allahabad    72      m    8101
# 4     shikha   32     b  allahabad    59      m    1354
# 5      khare   21     b    america    38      m    6211
# 6      singh   29     c      delhi    86      m    1595
# 7      padam   20     a  allahabad    74      f    8531
# 8     nirmal   22     c  allahabad    41      f    6595
# 9      singh   25     b  allahabad    75      f    2849
# 10    shikha   25     b      japan    48      m    7789
# 11  prashant   22     c  allahabad    62      f    7892
# 12    rishav   22     b      delhi    56      m    7557
# 13     singh   24     c      japan    59      m    5580
# 14     khare   34     b      delhi    77      m    6110
# 15     singh   32     a      delhi    92      m    2951
# ...

# %%
df.set_index("Name",inplace=True)

# %%
df
# Out:
#           Age Blood       city  temp gender  income  Index
# Name
# rishav     20     a      delhi    57      f    8626     11
# nirmal     21     a    america    58      f    4611     35
# nirmal     30     a    america    87      m    7032     12
# prashant   27     a  allahabad    72      m    8101     15
# shikha     32     b  allahabad    59      m    1354     35
# khare      21     b    america    38      m    6211     29
# singh      29     c      delhi    86      m    1595     46
# padam      20     a  allahabad    74      f    8531     28
# nirmal     22     c  allahabad    41      f    6595     26
# singh      25     b  allahabad    75      f    2849      5
# shikha     25     b      japan    48      m    7789     14
# prashant   22     c  allahabad    62      f    7892     29
# rishav     22     b      delhi    56      m    7557     45
# singh      24     c      japan    59      m    5580     16
# khare      34     b      delhi    77      m    6110     18
# ...

# %%
df.describe()
# Out:
#              Age       temp       income      Index
# count  50.000000  50.000000    50.000000  50.000000
# mean   26.120000  65.800000  5439.440000  22.980000
# std     4.443018  18.535129  2526.679358  14.199008
# min    20.000000  37.000000  1121.000000   1.000000
# 25%    22.000000  48.500000  2930.750000  11.000000
# 50%    26.500000  62.500000  5915.000000  21.000000
# 75%    30.000000  84.500000  7638.000000  34.750000
# max    34.000000  94.000000  9090.000000  49.000000

# %%
df.sort_index(axis=0,ascending=True)
# Out:
#           Age Blood       city  temp gender  income  Index
# Name
# khare      28     a      delhi    40      f    8814     10
# khare      21     c      delhi    73      m    4449      7
# khare      23     c    america    48      m    2839     39
# khare      21     b    america    42      f    7062     15
# khare      34     b      delhi    77      m    6110     18
# khare      20     c  allahabad    42      f    8277     11
# khare      21     b    america    38      m    6211     29
# nirmal     30     b    america    57      m    2924      7
# nirmal     30     a    america    87      m    7032     12
# nirmal     21     a    america    58      f    4611     35
# nirmal     26     c    america    82      f    4831     12
# nirmal     32     c      delhi    67      m    8644     45
# nirmal     28     b  allahabad    72      m    7081     13
# nirmal     22     c  allahabad    41      f    6595     26
# padam      21     a    america    94      f    9090     34
# ...

# %%
df.drop(["Index"],axis=1,inplace=True)

# %%
df
df.sort_index()
df.to_csv("nameageblood")

# %%
df
# Out:
#           Age Blood       city  temp gender  income
# Name
# rishav     20     a      delhi    57      f    8626
# nirmal     21     a    america    58      f    4611
# nirmal     30     a    america    87      m    7032
# prashant   27     a  allahabad    72      m    8101
# shikha     32     b  allahabad    59      m    1354
# khare      21     b    america    38      m    6211
# singh      29     c      delhi    86      m    1595
# padam      20     a  allahabad    74      f    8531
# nirmal     22     c  allahabad    41      f    6595
# singh      25     b  allahabad    75      f    2849
# shikha     25     b      japan    48      m    7789
# prashant   22     c  allahabad    62      f    7892
# rishav     22     b      delhi    56      m    7557
# singh      24     c      japan    59      m    5580
# khare      34     b      delhi    77      m    6110
# singh      32     a      delhi    92      m    2951
# nirmal     28     b  allahabad    72      m    7081
# ...
